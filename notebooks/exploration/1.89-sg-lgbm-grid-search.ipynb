# %%
import pandas as pd
import numpy as np
import os
import xgboost as xgb
from xgboost import plot_importance
from sklearn.metrics import mean_squared_error
from sklearn.base import TransformerMixin, BaseEstimator
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import random
import lightgbm
import shap
import itertools
pd.options.mode.chained_assignment = None

os.chdir('/Users/stevengeorge/Documents/Github/fpl-analysis/')

from src.data.gw_features import add_gw_features
from src.features.custom_transformers import TimeSeriesFeatures
from src.models.constants import TIME_SERIES_FEATURES, STATIC_FEATURES

# %matplotlib inline
pd.set_option('display.max_columns', None)
DATA_PATH = 'data/processed/'
# Out:
# /anaconda3/envs/fpl_analysis/lib/python3.7/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
fpl_data_all_seasons_with_ts = pd.read_parquet('fpl_data_all_seasons_with_ts.parquet')

# %%
training = fpl_data_all_seasons_with_ts[fpl_data_all_seasons_with_ts['season_order'].isin([1, 2])]

# %%
training = training[~((training['season_order'] == 2) & (training['gw'] == 38))]

# %%
mean_total_points = training['total_points'].mean()
mean_total_points
# Out:
# 1.3516271434592604

# %%
# Target cannot contain any nulls
training['total_points_plus_1_gw'] = training.groupby(['name'])['total_points'].shift(-1).fillna(mean_total_points)

# %%
training.drop(
    ['total_points', 'name', 'season', 'team_name', 'team_name_opponent'],
    axis=1,
    inplace=True
)

# %%
print(training.shape)
training = training[~training['next_match_was_home'].isnull()]
training['next_match_was_home'] = training['next_match_was_home'].astype(bool)
training.shape
# Out:
# (45079, 500)
# (44850, 500)

# %%
from sklearn.model_selection import GridSearchCV

# %%
lgmb_model = lightgbm.LGBMRegressor()
lgmb_model
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.1, max_depth=-1,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#               random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
params = {
    'num_leaves': [31, 50],
    'max_depth': [3, 7, -1],
    'learning_rate': [0.03, 0.1, 0.3],
    'n_estimators': [100, 200],
    'reg_alpha': [0, 0.03, 0.1]
}

# %%
grid_search = GridSearchCV(lightgbm.LGBMRegressor(), params, cv=3, scoring='neg_mean_squared_error', verbose=4)

# %%
# %%time
grid_search.fit(
    training.drop(['total_points_plus_1_gw', 'ID'], axis=1),
    training['total_points_plus_1_gw']
)
# Out:
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# [CV] learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0, score=-4.105, total=   8.4s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    8.4s remaining:    0.0s
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0, score=-4.391, total=   8.5s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   17.0s remaining:    0.0s
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0, score=-4.570, total=   8.3s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.03
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   25.3s remaining:    0.0s
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.03, score=-4.105, total=   9.0s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.03, score=-4.391, total=   8.4s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.03, score=-4.570, total=   9.5s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.1, score=-4.105, total=   8.3s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.1, score=-4.388, total=   9.1s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.1, score=-4.570, total=   8.4s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0, score=-4.105, total=   8.8s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0, score=-4.391, total=   9.7s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0, score=-4.570, total=  14.3s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.03, score=-4.105, total=  10.4s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.03, score=-4.391, total=  11.3s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.03, score=-4.570, total=   9.8s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.1, score=-4.105, total=  11.1s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.1, score=-4.388, total=  10.5s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.1, score=-4.570, total=  10.7s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0, score=-4.084, total=  11.9s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0, score=-4.367, total=  13.1s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0, score=-4.546, total=  13.1s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0.03, score=-4.084, total=  15.1s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0.03, score=-4.366, total=  14.9s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0.03, score=-4.545, total=  13.3s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0.1, score=-4.082, total=  11.8s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0.1, score=-4.363, total=  12.8s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0.1, score=-4.544, total=  11.9s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=50, reg_alpha=0, score=-4.084, total=  13.7s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=50, reg_alpha=0, score=-4.367, total=  12.1s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=50, reg_alpha=0, score=-4.546, total=  12.7s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=50, reg_alpha=0.03, score=-4.084, total=  12.3s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=50, reg_alpha=0.03, score=-4.366, total=  13.0s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=50, reg_alpha=0.03, score=-4.545, total=  12.1s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=50, reg_alpha=0.1, score=-4.082, total=  12.8s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=50, reg_alpha=0.1, score=-4.363, total=  12.3s
# [CV] learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=3, n_estimators=200, num_leaves=50, reg_alpha=0.1, score=-4.544, total=  14.4s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0, score=-4.071, total=  15.7s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0, score=-4.357, total=  14.7s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0, score=-4.535, total=  15.0s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.03, score=-4.069, total=  16.1s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.03, score=-4.356, total=  15.3s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.03, score=-4.533, total=  15.9s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.1, score=-4.074, total=  14.0s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.1, score=-4.363, total=  14.5s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.1, score=-4.535, total=  13.6s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0, score=-4.062, total=  16.1s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0, score=-4.345, total=  15.3s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0, score=-4.531, total=  16.5s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.03, score=-4.061, total=  16.0s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.03, score=-4.352, total=  16.7s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.03, score=-4.534, total=  16.0s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.1, score=-4.063, total=  16.7s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.1, score=-4.347, total=  15.6s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.1, score=-4.525, total=  17.5s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0, score=-4.064, total=  20.8s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0, score=-4.348, total=  21.4s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0, score=-4.546, total=  21.2s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.03, score=-4.062, total=  23.0s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.03, score=-4.347, total=  21.2s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.03, score=-4.544, total=  22.1s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.1, score=-4.066, total=  22.7s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.1, score=-4.348, total=  23.1s
# [CV] learning_rate=0.03, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.03, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.1, score=-4

# [CV] learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.03, score=-4.483, total=   9.0s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.03, score=-4.716, total=   8.0s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.1, score=-4.223, total=   8.5s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.1, score=-4.488, total=   8.8s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=31, reg_alpha=0.1, score=-4.742, total=   7.7s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0, score=-4.239, total=   8.3s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0, score=-4.431, total=   8.8s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0, score=-4.692, total=   7.7s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.03, score=-4.239, total=   8.1s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.03, score=-4.483, total=   8.5s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.03, score=-4.716, total=   7.7s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.1, score=-4.223, total=   8.2s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.1, score=-4.488, total=   8.2s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=100, num_leaves=50, reg_alpha=0.1, score=-4.742, total=   7.9s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0, score=-4.366, total=  10.7s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0, score=-4.519, total=  10.9s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0, score=-4.844, total=  10.3s
# [CV] learning_rate=0.3, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=200, num_leaves=31, reg_alpha=0.03, score=-4.359, total=  10.7s
# ...
# [CV] learning_rate=0.3, max_depth=3, n_estimators=200, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=3, n_estimators=200, num_leaves=50, reg_alpha=0.1, score=-4.876, total=  10.2s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0, score=-4.464, total=  11.8s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0, score=-4.714, total=  11.8s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0, score=-5.004, total=  11.0s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.03, score=-4.416, total=  12.3s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.03, score=-4.749, total=  12.0s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.03, score=-5.045, total=  11.4s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.1, score=-4.503, total=  12.1s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.1, score=-4.731, total=  11.9s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=31, reg_alpha=0.1, score=-5.025, total=  11.2s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0, score=-4.466, total=  12.6s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0, score=-4.801, total=  12.6s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0, score=-5.104, total=  12.4s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.03, score=-4.539, total=  12.9s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.03, score=-4.721, total=  13.2s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.03, score=-5.076, total=  12.2s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.1, score=-4.552, total=  13.1s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.1, score=-4.771, total=  13.3s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=100, num_leaves=50, reg_alpha=0.1, score=-5.071, total=  13.4s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0, score=-4.634, total=  17.4s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0, score=-4.865, total=  17.3s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0, score=-5.172, total=  16.9s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.03, score=-4.613, total=  17.5s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.03, score=-4.870, total=  17.5s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.03, score=-5.192, total=  17.1s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.1, score=-4.648, total=  17.8s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.1, score=-4.874, total=  17.7s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=31, reg_alpha=0.1, score=-5.160, total=  17.0s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=50, reg_alpha=0, score=-4.595, total=  20.3s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=50, reg_alpha=0, score=-4.951, total=  19.8s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=50, reg_alpha=0, score=-5.232, total=  19.8s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=50, reg_alpha=0.03, score=-4.680, total=  20.2s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=50, reg_alpha=0.03, score=-4.860, total=  19.9s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=50, reg_alpha=0.03, score=-5.240, total=  19.5s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=50, reg_alpha=0.1, score=-4.689, total=  20.4s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=50, reg_alpha=0.1, score=-4.863, total=  20.0s
# [CV] learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=7, n_estimators=200, num_leaves=50, reg_alpha=0.1, score=-5.229, total=  20.4s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=31, reg_alpha=0, score=-4.430, total=  12.2s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=31, reg_alpha=0, score=-4.721, total=  12.7s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=31, reg_alpha=0, score=-4.992, total=  11.4s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=31, reg_alpha=0.03, score=-4.447, total=  12.0s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=31, reg_alpha=0.03, score=-4.693, total=  12.3s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=31, reg_alpha=0.03, score=-5.038, total=  11.5s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=31, reg_alpha=0.1, score=-4.425, total=  12.4s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=31, reg_alpha=0.1, score=-4.763, total=  12.5s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=31, reg_alpha=0.1, score=-5.044, total=  12.1s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=50, reg_alpha=0, score=-4.612, total=  14.9s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=50, reg_alpha=0, score=-4.808, total=  15.0s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=50, reg_alpha=0, score=-5.167, total=  14.3s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=50, reg_alpha=0.03, score=-4.594, total=  15.0s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=50, reg_alpha=0.03, score=-4.787, total=  14.8s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=50, reg_alpha=0.03, score=-5.151, total=  14.6s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=50, reg_alpha=0.1, score=-4.555, total=  15.0s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=50, reg_alpha=0.1, score=-4.791, total=  14.6s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=100, num_leaves=50, reg_alpha=0.1, score=-5.076, total=  14.5s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=31, reg_alpha=0, score=-4.570, total=  18.2s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=31, reg_alpha=0, score=-4.850, total=  18.3s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=31, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=31, reg_alpha=0, score=-5.132, total=  17.5s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=31, reg_alpha=0.03, score=-4.607, total=  18.1s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=31, reg_alpha=0.03, score=-4.817, total=  18.2s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=31, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=31, reg_alpha=0.03, score=-5.217, total=  17.3s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=31, reg_alpha=0.1, score=-4.567, total=  18.5s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=31, reg_alpha=0.1, score=-4.918, total=  18.4s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=31, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=31, reg_alpha=0.1, score=-5.185, total=  18.1s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=50, reg_alpha=0, score=-4.699, total=  23.3s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=50, reg_alpha=0, score=-4.910, total=  23.3s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=50, reg_alpha=0
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=50, reg_alpha=0, score=-5.255, total=  23.0s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=50, reg_alpha=0.03, score=-4.726, total=  23.2s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=50, reg_alpha=0.03, score=-4.888, total=  23.4s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=50, reg_alpha=0.03
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=50, reg_alpha=0.03, score=-5.277, total=  22.6s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=50, reg_alpha=0.1, score=-4.657, total=  23.3s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=50, reg_alpha=0.1, score=-4.874, total=  24.0s
# [CV] learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=50, reg_alpha=0.1
# [CV]  learning_rate=0.3, max_depth=-1, n_estimators=200, num_leaves=50, reg_alpha=0.1, score=-5.184, total=  23.3s
# [Parallel(n_jobs=1)]: Done 324 out of 324 | elapsed: 88.9min finished
# CPU times: user 4h 6min 7s, sys: 11min 34s, total: 4h 17min 41s
# Wall time: 1h 29min 27s
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=LGBMRegressor(boosting_type='gbdt', class_weight=None,
#                                      colsample_bytree=1.0,
#                                      importance_type='split', learning_rate=0.1,
#                                      max_depth=-1, min_child_samples=20,
#                                      min_child_weight=0.001, min_split_gain=0.0,
#                                      n_estimators=100, n_jobs=-1, num_leaves=31,
#                                      objective=None, random_state=None,
#                                      reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                                      subsample=1.0, subsample_for_bin=200000,
#                                      subsample_freq=0),
#              iid='warn', n_jobs=None,
#              param_grid={'learning_rate': [0.03, 0.1, 0.3],
#                          'max_depth': [3, 7, -1], 'n_estimators': [100, 200],
#                          'num_leaves': [31, 50], 'reg_alpha': [0, 0.03, 0.1]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='neg_mean_squared_error', verbose=4)

# %%
grid_search.best_score_
# Out:
# -4.304288680344856

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.03,
#  'max_depth': -1,
#  'n_estimators': 200,
#  'num_leaves': 50,
#  'reg_alpha': 0.03}
