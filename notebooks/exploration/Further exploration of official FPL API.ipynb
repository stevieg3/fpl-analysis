# %% [markdown]
# # Further exploration of official FPL API

# %% [markdown]
# # Set-up

# %%
import os
import requests
import getpass
import pandas as pd
import numpy as np
import json

# %%
os.chdir('../..')

# %%
from src.data.live_season_data import _get_fpl_json

# %%
TEAM_ID = 2852128

# %%
MY_TEAM_URL = 'https://fantasy.premierleague.com/api/my-team/{}/'

# %% [markdown]
# # Access API endpoints which require authentication

# %% [markdown]
# Existing method will throw an HTTPError

# %%
_get_fpl_json(MY_TEAM_URL.format(TEAM_ID))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-6-786afa88609b> in <module>
# ----> 1 _get_fpl_json(MY_TEAM_URL.format(TEAM_ID))
#
# ~/Documents/Github/fpl-analysis/src/data/live_season_data.py in _get_fpl_json(url)
#     239     :return: JSON file
#     240     """
# --> 241     with urllib.request.urlopen(url) as open_url:
#     242         json_file = json.loads(open_url.read())
#     243     return json_file
#
# ~/opt/anaconda3/envs/fpl-analysis/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/opt/anaconda3/envs/fpl-analysis/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/opt/anaconda3/envs/fpl-analysis/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~/opt/anaconda3/envs/fpl-analysis/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~/opt/anaconda3/envs/fpl-analysis/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/opt/anaconda3/envs/fpl-analysis/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %% [markdown]
# Some parts of API require authentication. This can be achieved by following the steps outlined in this guide: https://medium.com/@bram.vanherle1/fantasy-premier-league-api-authentication-guide-2f7aeb2382e4

# %%
session = requests.session()

# %%
response = session.get(MY_TEAM_URL.format(TEAM_ID))
print(response)
# Out:
# <Response [403]>

# %%
url = 'https://users.premierleague.com/accounts/login/'

fpl_email = getpass.getpass(prompt='Email: ')
fpl_password = getpass.getpass(prompt='Password: ')

payload = {
 'password': fpl_password,
 'login': fpl_email,
 'redirect_uri': 'https://fantasy.premierleague.com/a/login',
 'app': 'plfpl-web'
}

session.post(url, data=payload)
# Out:
# Email:  ···························
# Password:  ·········
# <Response [200]>

# %%
response = session.get(MY_TEAM_URL.format(TEAM_ID))
print(response)
# Out:
# <Response [200]>

# %%
response.status_code == 200
# Out:
# True

# %%
team_data_json = json.loads(response.text)
team_data_json
# Out:
# {'picks': [{'element': 93,
#    'position': 1,
#    'selling_price': 47,
#    'multiplier': 1,
#    'purchase_price': 46,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 122,
#    'position': 2,
#    'selling_price': 53,
#    'multiplier': 1,
#    'purchase_price': 53,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 182,
#    'position': 3,
#    'selling_price': 75,
#    'multiplier': 1,
#    'purchase_price': 72,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 183,
#    'position': 4,
#    'selling_price': 65,
#    'multiplier': 1,
#    'purchase_price': 65,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 443,
#    'position': 5,
#    'selling_price': 54,
#    'multiplier': 1,
#    'purchase_price': 54,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 215,
#    'position': 6,
#    'selling_price': 103,
#    'multiplier': 2,
#    'purchase_price': 101,
#    'is_captain': True,
#    'is_vice_captain': False},
#   {'element': 29,
#    'position': 7,
#    'selling_price': 64,
#    'multiplier': 1,
#    'purchase_price': 66,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 191,
#    'position': 8,
#    'selling_price': 126,
#    'multiplier': 1,
#    'purchase_price': 125,
#    'is_captain': False,
#    'is_vice_captain': True},
#   {'element': 147,
#    'position': 9,
#    'selling_price': 62,
#    'multiplier': 1,
#    'purchase_price': 59,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 362,
#    'position': 10,
#    'selling_price': 62,
#    'multiplier': 1,
#    'purchase_price': 63,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 409,
#    'position': 11,
#    'selling_price': 78,
#    'multiplier': 1,
#    'purchase_price': 76,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 471,
#    'position': 12,
#    'selling_price': 51,
#    'multiplier': 0,
#    'purchase_price': 50,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 287,
#    'position': 13,
#    'selling_price': 47,
#    'multiplier': 0,
#    'purchase_price': 49,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 42,
#    'position': 14,
#    'selling_price': 47,
#    'multiplier': 0,
#    'purchase_price': 48,
#    'is_captain': False,
#    'is_vice_captain': False},
#   {'element': 336,
#    'position': 15,
#    'selling_price': 49,
#    'multiplier': 0,
#    'purchase_price': 50,
#    'is_captain': False,
#    'is_vice_captain': False}],
#  'chips': [{'status_for_entry': 'played',
#    'played_by_entry': [25],
#    'name': 'wildcard',
#    'number': 1,
#    'start_event': 21,
#    'stop_event': 38,
#    'chip_type': 'transfer'},
#   {'status_for_entry': 'played',
#    'played_by_entry': [9],
#    'name': 'freehit',
#    'number': 1,
#    'start_event': 2,
#    'stop_event': 38,
#    'chip_type': 'transfer'},
#   {'status_for_entry': 'available',
#    'played_by_entry': [],
#    'name': 'bboost',
#    'number': 1,
#    'start_event': 1,
#    'stop_event': 38,
#    'chip_type': 'team'},
#   {'status_for_entry': 'available',
#    'played_by_entry': [],
#    'name': '3xc',
#    'number': 1,
#    'start_event': 1,
#    'stop_event': 38,
#    'chip_type': 'team'}],
#  'transfers': {'cost': 4,
#   'status': 'cost',
#   'limit': 2,
#   'made': 0,
#   'bank': 16,
#   'value': 1001}}

# %%
team_data_json.keys()
# Out:
# dict_keys(['picks', 'chips', 'transfers'])

# %%
pd.json_normalize(team_data_json, 'picks')
# Out:
#     element  position  selling_price  multiplier  purchase_price  is_captain  \
# 0        93         1             47           1              46       False
# 1       122         2             53           1              53       False
# 2       182         3             75           1              72       False
# 3       183         4             65           1              65       False
# 4       443         5             54           1              54       False
# 5       215         6            103           2             101        True
# 6        29         7             64           1              66       False
# 7       191         8            126           1             125       False
# 8       147         9             62           1              59       False
# 9       362        10             62           1              63       False
# 10      409        11             78           1              76       False
# 11      471        12             51           0              50       False
# 12      287        13             47           0              49       False
# 13       42        14             47           0              48       False
# 14      336        15             49           0              50       False
#
#     is_vice_captain
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# 5             False
# 6             False
# 7              True
# 8             False
# 9             False
# 10            False
# 11            False
# 12            False
# 13            False
# 14            False

# %%
pd.json_normalize(team_data_json, 'chips')
# Out:
#   status_for_entry played_by_entry      name  number  start_event  stop_event  \
# 0           played            [25]  wildcard       1           21          38
# 1           played             [9]   freehit       1            2          38
# 2        available              []    bboost       1            1          38
# 3        available              []       3xc       1            1          38
#
#   chip_type
# 0  transfer
# 1  transfer
# 2      team
# 3      team

# %%
test = pd.json_normalize(team_data_json, 'chips')
test
# Out:
#   status_for_entry played_by_entry      name  number  start_event  stop_event  \
# 0           played            [25]  wildcard       1           21          38
# 1           played             [9]   freehit       1            2          38
# 2        available              []    bboost       1            1          38
# 3        available              []       3xc       1            1          38
#
#   chip_type
# 0  transfer
# 1  transfer
# 2      team
# 3      team

# %%
list(test[test['status_for_entry'] == 'available']['name'])
# Out:
# ['bboost', '3xc']

# %%
team_data_json['transfers']
# Out:
# {'cost': 4, 'status': 'cost', 'limit': 2, 'made': 0, 'bank': 16, 'value': 1001}

# %%
player_data_json = _get_fpl_json("https://fantasy.premierleague.com/api/bootstrap-static/")
players_raw = pd.json_normalize(player_data_json, 'elements')

# %%
players_raw.head()
# Out:
#    chance_of_playing_next_round  chance_of_playing_this_round    code  \
# 0                         100.0                         100.0   69140
# 1                         100.0                         100.0   98745
# 2                          75.0                          75.0  111457
# 3                         100.0                         100.0  154043
# 4                         100.0                         100.0   39476
#
#    cost_change_event  cost_change_event_fall  cost_change_start  \
# 0                  0                       0                 -4
# 1                  0                       0                  0
# 2                  0                       0                 -3
# 3                  0                       0                 -5
# 4                  0                       0                 -2
#
#    cost_change_start_fall  dreamteam_count  element_type ep_next  ... threat  \
# 0                       4                0             2     0.0  ...  107.0
# 1                       0                0             2     0.0  ...   38.0
# 2                       3                0             2     0.0  ...   67.0
# 3                       5                1             2     0.0  ...   37.0
# 4                       2                1             2     0.0  ...  110.0
#
#    ict_index influence_rank influence_rank_type  creativity_rank  \
# 0       29.8            289                 113              383
# 1       19.5            328                 129              329
# 2       41.2            279                 110              195
# 3       44.9            225                  89              199
# 4       58.5            105                  37              331
#
#    creativity_rank_type threat_rank threat_rank_type  ict_index_rank  \
# 0                   141         246               68             330
# 1                   112         338              118             366
# 2                    47         294               93             289
# 3                    48         339              119             271
# 4                   113         241               65             214
#
#   ict_index_rank_type
# 0                 117
# 1                 132
# 2                 101
# 3                  89
# 4                  62
#
# [5 rows x 61 columns]

# %%
player_data_response = session.get("https://fantasy.premierleague.com/api/bootstrap-static/")
player_data_json = json.loads(player_data_response.text)

# %%
players_raw = pd.json_normalize(player_data_json, 'elements')
players_raw.head()
# Out:
#    chance_of_playing_next_round  chance_of_playing_this_round    code  \
# 0                         100.0                         100.0   69140
# 1                         100.0                         100.0   98745
# 2                          75.0                          75.0  111457
# 3                         100.0                         100.0  154043
# 4                         100.0                         100.0   39476
#
#    cost_change_event  cost_change_event_fall  cost_change_start  \
# 0                  0                       0                 -4
# 1                  0                       0                  0
# 2                  0                       0                 -3
# 3                  0                       0                 -5
# 4                  0                       0                 -2
#
#    cost_change_start_fall  dreamteam_count  element_type ep_next  ... threat  \
# 0                       4                0             2     0.0  ...  107.0
# 1                       0                0             2     0.0  ...   38.0
# 2                       3                0             2     0.0  ...   67.0
# 3                       5                1             2     0.0  ...   37.0
# 4                       2                1             2     0.0  ...  110.0
#
#    ict_index influence_rank influence_rank_type  creativity_rank  \
# 0       29.8            289                 113              383
# 1       19.5            328                 129              329
# 2       41.2            279                 110              195
# 3       44.9            225                  89              199
# 4       58.5            105                  37              331
#
#    creativity_rank_type threat_rank threat_rank_type  ict_index_rank  \
# 0                   141         246               68             330
# 1                   112         338              118             366
# 2                    47         294               93             289
# 3                    48         339              119             271
# 4                   113         241               65             214
#
#   ict_index_rank_type
# 0                 117
# 1                 132
# 2                 101
# 3                  89
# 4                  62
#
# [5 rows x 61 columns]

# %%
players_raw.shape
# Out:
# (628, 61)

# %%
players_raw[players_raw['id'] == 215]['second_name']
# Out:
# 319    De Bruyne
# Name: second_name, dtype: object

# %%
team_data = pd.json_normalize(team_data_json, 'picks')
print(team_data.shape)
team_data.head()
# Out:
# (15, 7)
#    element  position  selling_price  multiplier  purchase_price  is_captain  \
# 0       93         1             47           1              46       False
# 1      122         2             53           1              53       False
# 2      182         3             75           1              72       False
# 3      183         4             65           1              65       False
# 4      443         5             54           1              54       False
#
#    is_vice_captain
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False

# %%
team_data = team_data.merge(
    players_raw[['id', 'first_name', 'second_name']],
    left_on='element',
    right_on='id'
)

team_data['name'] = team_data['first_name'] + '_' + team_data['second_name']
team_data['name'] = team_data['name'].str.lower()

# %%
team_data
# Out:
#     element  position  selling_price  multiplier  purchase_price  is_captain  \
# 0        93         1             47           1              46       False
# 1       122         2             53           1              53       False
# 2       182         3             75           1              72       False
# 3       183         4             65           1              65       False
# 4       443         5             54           1              54       False
# 5       215         6            103           2             101        True
# 6        29         7             64           1              66       False
# 7       191         8            126           1             125       False
# 8       147         9             62           1              59       False
# 9       362        10             62           1              63       False
# 10      409        11             78           1              76       False
# 11      471        12             51           0              50       False
# 12      287        13             47           0              49       False
# 13       42        14             47           0              48       False
# 14      336        15             49           0              50       False
#
#     is_vice_captain   id first_name       second_name                    name
# 0             False   93       Nick              Pope               nick_pope
# 1             False  122      Aaron       Wan-Bissaka       aaron_wan-bissaka
# 2             False  182      Trent  Alexander-Arnold  trent_alexander-arnold
# 3             False  183     Virgil          van Dijk         virgil_van dijk
# 4             False  443    Rodrigo         Hernandez       rodrigo_hernandez
# 5             False  215      Kevin         De Bruyne         kevin_de bruyne
# 6             False   29       Jack          Grealish           jack_grealish
# 7              True  191    Mohamed             Salah           mohamed_salah
# 8             False  147    Dominic     Calvert-Lewin   dominic_calvert-lewin
# 9             False  362       Troy            Deeney             troy_deeney
# 10            False  409       Raúl           Jiménez            raúl_jiménez
# 11            False  471       Dean         Henderson          dean_henderson
# 12            False  287       Todd          Cantwell           todd_cantwell
# 13            False   42      Lewis              Dunk              lewis_dunk
# 14            False  336      Serge            Aurier            serge_aurier

# %%
np.round((team_data['selling_price'].sum() / 10) + (team_data_json['transfers']['bank'] / 10), 2)
# Out:
# 99.9
